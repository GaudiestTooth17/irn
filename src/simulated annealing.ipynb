# %%
using LightGraphs, GraphPlot
include("fileio.jl")
include("static-graph-sa.jl")

# %%
M = find_resilient_spatial_network(2500, 0.0, .1, 1);
G = Graph(M);
# Out:
# Beginning.
# 0.0%┣                                         ┫ 0/2500 [00:00<-2:-5, -20.0 it/s]
# Energy: 276.382 0.0%┣                         ┫ 1/2500 [00:05<Inf:Inf, 0.0 it/s]
# Energy: 273.653 0.1%┣                        ┫ 2/2500 [00:07<04:43:35, 0.1 it/s]
# Energy: 273.603 0.1%┣                        ┫ 3/2500 [00:09<03:05:40, 0.2 it/s]
# Energy: 273.603 0.2%┣                        ┫ 4/2500 [00:11<02:33:48, 0.3 it/s]
# Energy: 273.603 0.2%┣                        ┫ 5/2500 [00:13<02:16:55, 0.3 it/s]
# Energy: 273.603 0.2%┣                        ┫ 6/2500 [00:15<02:07:16, 0.3 it/s]
# Energy: 273.549 0.3%┣                        ┫ 7/2500 [00:17<02:00:53, 0.3 it/s]
# Energy: 272.986 0.3%┣                        ┫ 8/2500 [00:20<01:56:33, 0.4 it/s]
# Energy: 272.623 0.4%┣                        ┫ 9/2500 [00:22<01:52:57, 0.4 it/s]
# Energy: 272.623 0.4%┣                       ┫ 10/2500 [00:24<01:50:11, 0.4 it/s]
# ...

# %%
gplot(G)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.5026205190851091cx, -0.04203900354374032cy), (0.5147438132068319cx, -0.05256735664645232cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.5175028123576633cx, -0.04023121212231169cy), (0.5218017017
# ...

# %%
is_connected(G)
# Out:
# false

# %%
length(edges(G))
# Out:
# 3581

# %%
N = length(vertices(G))
length(edges(G))/(N*(N-1)÷2)
# Out:
# 0.028705410821643285

# %%
(maximum(degree(G)), minimum(degree(G)))
# Out:
# (44, 0)

# %%
diameter(G)
# Out:
# ┌ Warning: Infinite path length detected for vertex 1
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 2
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 3
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 4
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 5
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 6
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 7
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ...

# %%
write_adj_list("../annealed-social-circles-.05-1.txt", M)
