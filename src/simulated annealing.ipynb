# %%
using LightGraphs, GraphPlot
include("fileio.jl")
include("static-graph-sa.jl")

# %%
M = find_resilient_spatial_network(2500, 0.0, .05, 1);
G = Graph(M);
# Out:
# Beginning.
# 0.0%┣                                         ┫ 0/2500 [00:00<-2:-5, -20.0 it/s]
# 0.0%┣                                         ┫ 1/2500 [00:06<Inf:Inf, 0.0 it/s]
# 0.1%┣                                        ┫ 2/2500 [00:09<05:59:06, 0.1 it/s]
# 0.1%┣                                        ┫ 3/2500 [00:11<03:44:05, 0.2 it/s]
# 0.2%┣                                        ┫ 4/2500 [00:13<02:58:42, 0.2 it/s]
# 0.2%┣                                        ┫ 5/2500 [00:15<02:36:10, 0.3 it/s]
# 0.2%┣                                        ┫ 6/2500 [00:17<02:22:27, 0.3 it/s]
# 0.3%┣▏                                       ┫ 7/2500 [00:19<02:13:17, 0.3 it/s]
# 0.3%┣▏                                       ┫ 8/2500 [00:21<02:06:54, 0.3 it/s]
# 0.4%┣▏                                       ┫ 9/2500 [00:24<02:03:45, 0.3 it/s]
# 0.4%┣▏                                      ┫ 10/2500 [00:27<02:03:07, 0.3 it/s]
# ...

# %%
gplot(G)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.2775085183296532cx, 0.12810955038215366cy), (0.3091239073614599cx, 0.09406443960165145cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.27904413435828074cx, 0.12986826093709197cy), (0.296681808055
# ...

# %%
is_connected(G)
# Out:
# false

# %%
length(edges(G))
# Out:
# 2136

# %%
N = length(vertices(G))
length(edges(G))/(N*(N-1)÷2)
# Out:
# 0.017122244488977957

# %%
(maximum(degree(G)), minimum(degree(G)))
# Out:
# (19, 1)

# %%
diameter(G)
# Out:
# ┌ Warning: Infinite path length detected for vertex 1
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 2
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 3
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 4
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 5
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 6
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ┌ Warning: Infinite path length detected for vertex 7
# └ @ LightGraphs /home/alex/.julia/packages/LightGraphs/siFgP/src/distance.jl:74
# ...

# %%
write_adj_list("../annealed-social-circles.txt", M)
