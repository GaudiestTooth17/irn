# %%
using LightGraphs, GraphPlot
include("fileio.jl")
include("static-graph-sa.jl")
# G = Graph(read_adj_list("evolved.txt"));

# %%
ϵ = find_resilient_network(2500, 0.0);
G = Graph(encoding_to_adj_matrix(ϵ));
# Out:
# Beginning.
# 0.0%┣                                         ┫ 0/2500 [00:00<-2:-5, -20.0 it/s]
# Energy: -1.77 0.0%┣                           ┫ 1/2500 [00:00<Inf:Inf, 0.0 it/s]
# Energy: -1.77 0.1%┣                             ┫ 3/2500 [00:00<09:28, 4.4 it/s]
# Energy: -1.77 0.2%┣                             ┫ 5/2500 [00:01<05:28, 7.6 it/s]
# Energy: -1.77 0.3%┣                            ┫ 7/2500 [00:01<04:04, 10.2 it/s]
# Energy: -1.77 0.4%┣                            ┫ 9/2500 [00:01<03:25, 12.2 it/s]
# Energy: -1.77 0.4%┣▏                          ┫ 11/2500 [00:01<02:59, 13.9 it/s]
# Energy: -1.77 0.5%┣▏                          ┫ 13/2500 [00:01<02:43, 15.3 it/s]
# Energy: -1.77 0.6%┣▏                          ┫ 15/2500 [00:01<02:30, 16.5 it/s]
# Energy: -1.77 0.7%┣▏                          ┫ 17/2500 [00:01<02:22, 17.5 it/s]
# Energy: -1.77 0.8%┣▏                          ┫ 19/2500 [00:01<02:14, 18.5 it/s]
# ...

# %%
gplot(G)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.4871740132434952cx, 0.9024477860825096cy), (0.48715351742988466cx, 0.9120155943231817cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.504422786891646cx, 0.8955951413245526cy), (0.522306649199552c
# ...

# %%
is_connected(G)
# Out:
# true

# %%
length(edges(G))
# Out:
# 448

# %%
N = length(vertices(G))
length(edges(G))/(N*(N-1)÷2)
# Out:
# 0.0905050505050505

# %%
(maximum(degree(G)), minimum(degree(G)))
# Out:
# (11, 8)

# %%
diameter(G)
# Out:
# 18

# %%
write_adj_list("../annealed-large-diameter.txt", encoding_to_adj_matrix(ϵ))
